# %% [markdown]
# # Early Results Assignment

# %% [markdown]
# Dylan Johnson

# %% [markdown]
# # STEP 1: IMPORT, ADAPT, AND PRINT DATA

# %%
#import package
import pandas as pd

# read in the CSV file
data = pd.read_csv('NFL_DATA.csv')

# drop rows with all missing values
data.dropna(axis=0, how='all', inplace=True)

# drop columns with all missing values
data.dropna(axis=1, how='all', inplace=True)

# print the resulting dataframe
print(data)
# Out:
#           PLAYER NAME TEAM POS  CUSH  SEP   TAY   TAY%    REC    TAR  CTCH%  \
# 0    Justin Jefferson  MIN  WR   5.4  3.1  10.3  39.03  128.0  184.0  69.57
# 1         Tyreek Hill  MIA  WR   6.4  3.3  12.2  40.15  119.0  170.0  70.00
# 2       Davante Adams   LV  WR   5.6  2.9  12.1  41.77  100.0  180.0  55.56
# 3          A.J. Brown  PHI  WR   5.6  2.6  12.2  41.31   88.0  145.0  60.69
# 4        Stefon Diggs  BUF  WR   5.4  2.8  11.6  34.57  108.0  154.0  70.13
# ..                ...  ...  ..   ...  ...   ...    ...    ...    ...    ...
# 626       Zach Pascal  IND  WR   5.7  2.4   9.6   8.95   27.0   46.0  58.70
# 627      Ryan Switzer  PIT  WR   5.8  3.5   3.2   2.67   36.0   44.0  81.82
# 628  DaeSean Hamilton  DEN  WR   5.3  3.1   8.4   8.83   30.0   46.0  65.22
# 629         John Ross  CIN  WR   5.4  2.2  14.0  18.36   21.0   58.0  36.21
# 630     Chad Williams  ARI  WR   5.4  1.9  13.2  15.34   17.0   46.0  36.96
#
#         YDS    TD  YAC/R  xYAC/R  +/-    YEAR
# ...

# %% [markdown]
# # STEP 2: REGRESSION ANALYSIS
# First I want to look at the regression analysis of the recievers Separation in comparison to the columns that can be related to success.

# %%
#create regression model
#import packages
import pandas as pd
import statsmodels.api as sm

# specify the dependent variable and independent variables
y = data['SEP']
X = data[['TAY', 'TAY%', 'REC', 'TAR', 'CTCH%', 'YDS', 'TD', 'YAC/R', 'xYAC/R', '+/-']]

# add a constant term to the independent variables
X = sm.add_constant(X)

# create the multiple regression model
model = sm.OLS(y, X)

# fit the model to the data
results = model.fit()

# print the summary of the regression analysis
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    SEP   R-squared:                       0.576
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     84.36
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          1.02e-108
# Time:                        09:35:52   Log-Likelihood:                -188.33
# No. Observations:                 631   AIC:                             398.7
# Df Residuals:                     620   BIC:                             447.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2569      0.405      0.634      0.526      -0.538       1.052
# ...

# %%
# define the independent and dependent variables
x_var = 'SEP'
y_vars = ['TAY', 'TAY%', 'REC', 'TAR', 'CTCH%', 'YDS', 'TD', 'YAC/R', 'xYAC/R', '+/-']

# create subplots for each dependent variable
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))
axes = axes.ravel()

# loop through each dependent variable and create a scatter plot
for i, y_var in enumerate(y_vars):
    axes[i].scatter(df[x_var], df[y_var], alpha=0.5)
    axes[i].set_xlabel(x_var)
    axes[i].set_ylabel(y_var)
    axes[i].set_title(y_var)

# adjust spacing between subplots and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Separation and Total Air Yards

# %%
#import package
import statsmodels.api as sm

# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['TAY']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    TAY   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     322.5
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           1.58e-58
# Time:                        21:42:42   Log-Likelihood:                -1439.0
# No. Observations:                 631   AIC:                             2882.
# Df Residuals:                     629   BIC:                             2891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.1488      0.566     35.583      0.000      19.037      21.261
# ...

# %%
# specify the dependent variable and independent variables
y = data['SEP']
X = data[['TAY', 'TAY%', 'REC', 'TAR', 'CTCH%', 'YDS', 'TD', 'YAC/R', 'xYAC/R', '+/-']]

# add a constant term to the independent variables
X = sm.add_constant(X)

# create the multiple regression model
model = sm.OLS(y, X)

# fit the model to the data
results = model.fit()

# print the summary of the regression analysis
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    SEP   R-squared:                       0.576
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     84.36
# Date:                Fri, 10 Mar 2023   Prob (F-statistic):          1.02e-108
# Time:                        09:38:53   Log-Likelihood:                -188.33
# No. Observations:                 631   AIC:                             398.7
# Df Residuals:                     620   BIC:                             447.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2569      0.405      0.634      0.526      -0.538       1.052
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['TAY'])
plt.xlabel('SEP')
plt.ylabel('TAY')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and % of Teams Total Air Yards

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['TAY%']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   TAY%   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                  0.186
# Method:                 Least Squares   F-statistic:                     145.2
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           3.12e-30
# Time:                        21:43:09   Log-Likelihood:                -2218.0
# No. Observations:                 631   AIC:                             4440.
# Df Residuals:                     629   BIC:                             4449.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         42.6822      1.946     21.929      0.000      38.860      46.504
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['TAY%'])
plt.xlabel('SEP')
plt.ylabel('TAY%')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Receptions

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['REC']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    REC   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1489
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):              0.700
# Time:                        21:43:27   Log-Likelihood:                -2884.2
# No. Observations:                 631   AIC:                             5772.
# Df Residuals:                     629   BIC:                             5781.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         53.0255      5.594      9.479      0.000      42.040      64.011
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['REC'])
plt.xlabel('SEP')
plt.ylabel('REC')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Targets

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['TAR']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    TAR   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     9.830
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):            0.00180
# Time:                        21:43:41   Log-Likelihood:                -3093.5
# No. Observations:                 631   AIC:                             6191.
# Df Residuals:                     629   BIC:                             6200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        109.1255      7.795     14.000      0.000      93.818     124.433
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['TAR'])
plt.xlabel('SEP')
plt.ylabel('TAR')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Catch %

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['CTCH%']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  CTCH%   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     220.7
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           5.24e-43
# Time:                        21:44:11   Log-Likelihood:                -2091.2
# No. Observations:                 631   AIC:                             4186.
# Df Residuals:                     629   BIC:                             4195.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.1402      1.592     25.842      0.000      38.014      44.266
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['CTCH%'])
plt.xlabel('SEP')
plt.ylabel('CTCH%')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Yards

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['YDS']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    YDS   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     14.93
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           0.000123
# Time:                        21:44:29   Log-Likelihood:                -4520.1
# No. Observations:                 631   AIC:                             9044.
# Df Residuals:                     629   BIC:                             9053.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        970.2262     74.763     12.977      0.000     823.410    1117.042
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['YDS'])
plt.xlabel('SEP')
plt.ylabel('YDS')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Touchdowns

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['TD']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     TD   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6.700
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):            0.00987
# Time:                        21:44:42   Log-Likelihood:                -1558.8
# No. Observations:                 631   AIC:                             3122.
# Df Residuals:                     629   BIC:                             3131.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.1295      0.685      8.952      0.000       4.785       7.474
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['TD'])
plt.xlabel('SEP')
plt.ylabel('TD')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and YAC per Reception

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['YAC/R']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  YAC/R   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     116.5
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           5.02e-25
# Time:                        21:45:03   Log-Likelihood:                -1061.6
# No. Observations:                 631   AIC:                             2127.
# Df Residuals:                     629   BIC:                             2136.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3558      0.311      4.354      0.000       0.744       1.967
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['YAC/R'])
plt.xlabel('SEP')
plt.ylabel('YAC/R')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Expected YAC per Reception

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['xYAC/R']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 xYAC/R   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     331.2
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):           9.15e-60
# Time:                        21:47:32   Log-Likelihood:                -743.31
# No. Observations:                 631   AIC:                             1491.
# Df Residuals:                     629   BIC:                             1500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6996      0.188      3.721      0.000       0.330       1.069
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['xYAC/R'])
plt.xlabel('SEP')
plt.ylabel('xYAC/R')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()

# %% [markdown]
# # Separation and Avg YAC Above/Below Expectation

# %%
# Split the data into independent and dependent variables
X = data[['SEP']]
Y = data[['+/-']]

# Add a constant term to the independent variable
X = sm.add_constant(X)

# Perform the multiple linear regression analysis
model = sm.OLS(Y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    +/-   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1665
# Date:                Thu, 09 Mar 2023   Prob (F-statistic):              0.683
# Time:                        21:48:43   Log-Likelihood:                -785.70
# No. Observations:                 631   AIC:                             1575.
# Df Residuals:                     629   BIC:                             1584.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6731      0.201      3.347      0.001       0.278       1.068
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['SEP'], data['+/-'])
plt.xlabel('SEP')
plt.ylabel('+/-')
plt.title('Scatter Plot of SEP vs TAY')
plt.show()
